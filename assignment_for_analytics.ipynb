# %%
song_list = {1: {'Track': '1', 'Song': 'Like to party by Burna Boy', 'Duration': '3:05'},
              2: {'Track': '2', 'Song': 'Wizkid by Wizkid feat Drake', 'Duration': '3:54'},
              3: {'Track': '3', 'Song': 'Stars in the sky by Kid Cudi', 'Duration': '2:49'},
              4: {'Track': '4', 'Song': 'Booty Man by Craig Daid', 'Duration': '3.19'},
              5: {'Track': '5', 'Song': 'When i see you by Fantasia', 'Duration': '3.38'}
             }
print("Welcome to Kay's Gold Tunes!!\n\nPlease select a number berween the range of 1 to 5\n ")

user_selection = int(input('Please select a number between 1 and 5: '))
condition = False

while not condition:
    
    if not 1 <= user_selection <= 5:
        print('Out of range, Please select a number between 1 and 5')
        user_selection = int(input('Please select a number between 1 and 5: '))
        
    else:
        if user_selection in range(1, 6):
            print(f'You selected track: {song_list.get(user_selection)}')

        else:
            print('Thank you, come back soon')
            condition = True
# Out:
# Welcome to Kay's Gold Tunes!!
#
# Please select a number berween the range of 1 to 5

# %%
def minutes_converter(txt):
    mins = txt[0]
    secs = txt[2:]

    mins = int(mins)
    secs = int(secs)

    return mins * 60 + secs

minutes_converter('3:38')
# Out:
# 218

# %%
song_list = {1: {'Track': '1', 'Song': 'Like to party by Burna Boy', 'Duration': '185'},
              2: {'Track': '2', 'Song': 'Wizkid by Wizkid feat Drake', 'Duration': '234'},
              3: {'Track': '3', 'Song': 'Stars in the sky by Kid Cudi', 'Duration': '169'},
              4: {'Track': '4', 'Song': 'Booty Man by Craig Daid', 'Duration': '199'},
              5: {'Track': '5', 'Song': 'When i see you by Fantasia', 'Duration': '218'}
             }

print("Welcome to Kay's Gold Tunes!!\n")

user_selection = int(input(' Please select a number between 1 and 5: '))

while not (1 <= user_selection <= 5):
    print('Out of range, Please select a number between 1 and 5')
    user_selection = int(input('Please select a number between 1 and 5: '))

if user_selection in range(1, 5):

    song_min = int(song_list.get(user_selection).get('Duration')) // 60
    song_secs = int(song_list.get(user_selection).get('Duration')) % 60

    print(f"\nYou have selected track: {song_list.get(user_selection).get('Track')}")
    print(f"\nThe artist is: {song_list.get(user_selection).get('Song')}")
    print(f"\nTotal duration of the song is: {song_min}mins:{song_secs}secs")
    
    # print(f"You have selected track: {song_list.get(user_selection).get('Track')}")
# Out:
# Welcome to Kay's Gold Tunes!!
#  Please select a number between 1 and 5:  3
# You have selected track: 3
#
# The artist is: Stars in the sky by Kid Cudi
#
# Total duration of the song is: 2mins:49secs

# %%
#Declare variables to collect inputs
g_wge = input('Please enter in your gross wage')
no_children = input('please enter in the number of kids you have: ')
m_sts = input('Please select your marital status (m or s): ').lower() #Force the entered value to lower case.

#check if inputs are valid, is.digit confirms if the user entered a number.
if (
    not g_wge.isdigit() or int(g_wge) < 0 or 
    not no_children.isdigit() or int(no_children) < 0 or 
    m_sts not in ['m', 's'] #using the list makes it easier to catch if the input is outside the expected values.
    ):
    print('Invalid selection, please try again')
    
else:
    g_wge = int(g_wge)
    no_children = int(no_children)    

    #Logic to calculate child allowance
    c_allowance = no_children * 2000 #bucket child allowance

    #logic to calculate marital allowance
    if m_sts == 'm':
        m_allowance = 5000
    else:
        m_allowance = 2500

        #logic to calculate tax rate
        if g_wge < 20000:
            tax_rate = 0.20
        elif 20000 <= g_wge <= 35000:
            tax_rate = 0.25
        else:
            tax_rate = 0.4 * 100

            taxable_income = m_allowance + c_allowance

            print(f'\nGross wage: {g_wge}, Deductions: Child allowance: {child_allowance}, Marital Allowance: {m_allowance}')
            print(f'Taxable income: {taxable_income}')
            print(f'Tax: {tax_rate}%')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[138], line 2
#       1 #Declare variables to collect inputs
# ----> 2 g_wge = input('Please enter in your gross wage')
#       3 no_children = input('please enter in the number of kids you have: ')
#       4 m_sts = input('Please select your marital status (m or s): ').lower() #Force the entered value to lower case.
#
# File ~/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# ...

# %%
# Out:
# Please enter in your gross wage 5000
# please enter in the number of kids you have:  3
# Please select your marital status (m or s):  m
# exiting...
